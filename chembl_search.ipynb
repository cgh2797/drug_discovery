# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('chembl_bulk.tsv',sep='\t', error_bad_lines=False)
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#              ChEMBL ID                              Name  \
# 0        CHEMBL4250533                               NaN
# 1        CHEMBL4242655                               NaN
# 2        CHEMBL4249255                               NaN
# 3        CHEMBL4242272                               NaN
# 4        CHEMBL4247231                               NaN
# ...                ...                               ...
# 1961457  CHEMBL4298073  POLYETHYLENE GLYCOL, UNSPECIFIED
# 1961458     CHEMBL1224                       ACRIVASTINE
# 1961459  CHEMBL3707349                        AMCASERTIB
# 1961460  CHEMBL4297852                        CENEGERMIN
# 1961461  CHEMBL4297916                          BNC-105P
#
#                                                   Synonyms            Type  \
# 0                                                      NaN         Unknown
# 1                                                      NaN         Unknown
# ...

# %%
data['Name'].fillna('False',inplace=True)

# %%
data['Synonyms'].fillna('False',inplace=True)

# %%
data
# Out:
#              ChEMBL ID                              Name  \
# 0        CHEMBL4250533                             False
# 1        CHEMBL4242655                             False
# 2        CHEMBL4249255                             False
# 3        CHEMBL4242272                             False
# 4        CHEMBL4247231                             False
# ...                ...                               ...
# 1961457  CHEMBL4298073  POLYETHYLENE GLYCOL, UNSPECIFIED
# 1961458     CHEMBL1224                       ACRIVASTINE
# 1961459  CHEMBL3707349                        AMCASERTIB
# 1961460  CHEMBL4297852                        CENEGERMIN
# 1961461  CHEMBL4297916                          BNC-105P
#
#                                                   Synonyms            Type  \
# 0                                                    False         Unknown
# 1                                                    False         Unknown
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
filter=data['Name'].str.contains("nib")

# %%
filter2=data['Synonyms'].str.contains("nib")

# %%
filter
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1961457    False
# 1961458    False
# 1961459    False
# 1961460    False
# 1961461    False
# Name: Name, Length: 1961462, dtype: bool

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
test=data["Name"].str.lower().str.contains("nib")

# %%
test
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1961457    False
# 1961458    False
# 1961459    False
# 1961460    False
# 1961461    False
# Name: Name, Length: 1961462, dtype: bool

# %%
test1=data["Synonyms"].str.lower().str.contains("nib")

# %%
test1
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1961457    False
# 1961458    False
# 1961459    False
# 1961460    False
# 1961461    False
# Name: Synonyms, Length: 1961462, dtype: bool

# %%
filter=test|test1

# %%
nib=data[filter]

# %%
nib
# Out:
#              ChEMBL ID                  Name  \
# 137724   CHEMBL4297222   NAZARTINIB MESYLATE
# 168500   CHEMBL3544982  TESEVATINIB TOSYLATE
# 173634   CHEMBL1760433       [11C]-SORAFENIB
# 253344     CHEMBL56904                 False
# 274945   CHEMBL4297640          VECABRUTINIB
# ...                ...                   ...
# 1961266   CHEMBL255863             NILOTINIB
# 1961306  CHEMBL4297674         BRANEBRUTINIB
# 1961337  CHEMBL3545154            POZIOTINIB
# 1961351  CHEMBL1287853            FEDRATINIB
# 1961410  CHEMBL4208229             ASCIMINIB
#
#                                                   Synonyms            Type  \
# 137724                  NAZARTINIB MESYLATE|NVP-EGF816-AGA  Small molecule
# 168500                                TESEVATINIB TOSYLATE  Small molecule
# 173634                                     [11C]-Sorafenib  Small molecule
# 253344                                   Demethyl-imatinib  Small molecule
# ...

# %%
nib.to_excel('nib.xlsx', index=False)
