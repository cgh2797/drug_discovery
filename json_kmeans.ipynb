# %%
import json
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
from rdkit.Chem import MCS
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import rdFMCS
from rdkit import rdBase

from rdkit.Chem import rdMolDescriptors

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: The rdkit.Chem.MCS module is deprecated; please use rdkit.Chem.rdFMCS instead.
#   after removing the cwd from sys.path.

# %%
with open('nib_172.json', 'r') as f:

    json_data = json.load(f)

#print(json.dumps(json_data) )
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(json.dumps(json_data, indent="\t") )
# Out:
# {
# 	"version": 24.3,
# 	"renderTo": "canvas",
# 	"data": {
# 		"x": [],
# 		"y": {
# 			"vars": [
# 				"S_-TIPIFARNIB",
# 				"11C_-SORAFENIB",
# 				"5-_11C_methoxy-sunitinib",
# 				"5-iodo-sunitinib",
# 				"5-methoxy-sunitinib",
# 				"ABC-294640",
# 				"ABIVERTINIB",
# 				"ABROCITINIB",
# 				"ACALABRUTINIB",
# 				"AFATINIB",
# 				"AGERAFENIB",
# 				"ALECTINIB",
# 				"ALFLUTINIB",
# 				"ALLITINIB",
# 				"ALTIRATINIB",
# 				"AMUVATINIB",
# 				"ANLOTINIB",
# 				"ASCIMINIB",
# 				"AVAPRITINIB",
# 				"AXITINIB",
# 				"BAFETINIB",
# 				"BARICITINIB",
# 				"BELORANIB",
# 				"BEMCENTINIB",
# 				"BINIMETINIB",
# 				"BOSUTINIB",
# 				"BRANEBRUTINIB",
# 				"BREPOCITINIB",
# 				"BRIGATINIB",
# 				"BRIVANIB",
# 				"CABOZANTINIB",
# 				"CANERTINIB",
# 				"CAPMATINIB",
# 				"CEDIRANIB",
# 				"CERDULATINIB",
# 				"CERITINIB",
# 				"CHIAURANIB",
# 				"COBIMETINIB",
# 				"CRENOLANIB",
# 				"CRIZOTINIB",
# 				"DABRAFENIB",
# 				"DACOMITINIB",
# 				"DASATINIB",
# 				"DECERNOTINIB",
# 				"DEFACTINIB",
# 				"DELGOCITINIB",
# 				"Demethyl-imatinib",
# 				"DENIBULIN",
# 				"DERAZANTINIB",
# 				"DONAFENIB",
# 				"DOVITINIB",
# 				"DUBERMATINIB",
# 				"EDICOTINIB",
# 				"ENASIDENIB",
# 				"ENCORAFENIB",
# 				"ENSARTINIB",
# 				"ENTOSPLETINIB",
# 				"ENTRECTINIB",
# 				"ERDAFITINIB",
# 				"ERLOTINIB",
# 				"Evobrutinib",
# 				"FAMITINIB",
# 				"FEDRATINIB",
# 				"FENEBRUTINIB",
# 				"FILGOTINIB",
# 				"FLUMATINIB",
# 				"FORETINIB",
# 				"FOSLINANIB",
# 				"FOSTAMATINIB",
# 				"FRUQUINTINIB",
# 				"FUTIBATINIB",
# 				"GANDOTINIB",
# 				"GEFITINIB",
# 				"GILTERITINIB",
# 				"GLESATINIB",
# 				"GOLVATINIB",
# 				"HENATINIB",
# 				"IBRUTINIB",
# 				"ICOTINIB",
# 				"ILGINATINIB",
# 				"IMATINIB",
# 				"INFIGRATINIB",
# 				"ITACITINIB",
# 				"IVOSIDENIB",
# 				"LANRAPLENIB",
# 				"LAPATINIB",
# 				"LAROTRECTINIB",
# 				"LENVATINIB",
# 				"LIFIRAFENIB",
# 				"LINIFANIB",
# 				"LINSITINIB",
# 				"LONAFARNIB",
# 				"LORLATINIB",
# 				"LUCITANIB",
# 				"MASITINIB",
# 				"MAVELERTINIB",
# 				"MERESTINIB",
# 				"MOMELOTINIB",
# 				"MOTESANIB",
# 				"MUBRITINIB",
# 				"NAQUOTINIB",
# 				"NAZARTINIB",
# 				"NERATINIB",
# 				"NILOTINIB",
# 				"NINTEDANIB",
# 				"OCLACITINIB",
# 				"OLMUTINIB",
# 				"OLUTASIDENIB",
# 				"ORANTINIB",
# 				"OSIMERTINIB",
# 				"PACRITINIB",
# 				"PAZOPANIB",
# 				"PEFICITINIB",
# 				"PELITINIB",
# 				"PEMIGATINIB",
# 				"PEXIDARTINIB",
# 				"PEXMETINIB",
# 				"PONATINIB",
# 				"POSELTINIB",
# 				"POZIOTINIB",
# 				"PRALSETINIB",
# 				"PUQUITINIB",
# 				"PYROTINIB",
# 				"QUIZARTINIB",
# 				"RADOTINIB",
# 				"RALIMETINIB",
# 				"RAVOXERTINIB",
# 				"REBASTINIB",
# 				"REFAMETINIB",
# 				"REGORAFENIB",
# 				"REPOTRECTINIB",
# 				"RIPRETINIB",
# 				"RIVOCERANIB",
# 				"ROCILETINIB",
# 				"ROGARATINIB",
# 				"RUXOLITINIB",
# 				"SAPITINIB",
# 				"SARACATINIB",
# 				"SAVOLITINIB",
# 				"SELITRECTINIB",
# 				"SELUMETINIB",
# 				"SEMAXANIB",
# 				"SIMOTINIB",
# 				"SITRAVATINIB",
# 				"SOLCITINIB",
# 				"SORAFENIB",
# 				"SPEBRUTINIB",
# 				"SUNITINIB",
# 				"SURUFATINIB",
# 				"TAFETINIB",
# 				"TANDUTINIB",
# 				"TARLOXOTINIB",
# 				"TELATINIB",
# 				"TEPOTINIB",
# 				"TESEVATINIB",
# 				"THELIATINIB",
# 				"TIPIFARNIB",
# 				"TIRABRUTINIB",
# 				"TIVANTINIB",
# 				"TIVOZANIB",
# 				"TOFACITINIB",
# 				"TRAMETINIB",
# 				"TUCATINIB",
# 				"ULIXERTINIB",
# 				"UPADACITINIB",
# 				"VANDETANIB",
# 				"VARLITINIB",
# 				"VATALANIB",
# 				"VECABRUTINIB",
# 				"VEMURAFENIB",
# 				"VOROLANIB",
# 				"ZANUBRUTINIB"
# 			],
# 			"smps": [
# 				"V1",
# 				"V2"
# 			],
# 			"desc": [
# 				"clusters"
# 			],
# 			"data": [
# 				[
# 					-0.194565039350966,
# 					-0.0546363458646758
# 				],
# 				[
# 					-0.309891222082972,
# 					-0.144590723741781
# 				],
# 				[
# 					0.137403648489819,
# 					-0.23508013520163
# 				],
# 				[
# 					0.150344303149032,
# 					-0.250651152473512
# 				],
# 				[
# 					0.137403648489819,
# 					-0.23508013520163
# 				],
# 				[
# 					0.129690109686091,
# 					-0.00120839414441397
# 				],
# 				[
# 					-0.114066274242572,
# 					0.164992461247981
# 				],
# 				[
# 					0.24818785783469,
# 					-0.106750445114475
# 				],
# 				[
# 					-0.0184823363297602,
# 					0.0670884814756315
# 				],
# 				[
# 					0.00679487459449402,
# 					0.031489574273064
# 				],
# 				[
# 					-0.218390172849396,
# 					-0.0837519397762979
# 				],
# 				[
# 					0.217372236427897,
# 					0.0404986764202935
# 				],
# 				[
# 					-0.0780960774392231,
# 					0.0469906685929289
# 				],
# 				[
# 					-0.26411033270398,
# 					0.0325702822423066
# 				],
# 				[
# 					-0.110657802533004,
# 					0.00467346106131276
# 				],
# 				[
# 					0.0795320064311754,
# 					0.167165118908723
# 				],
# 				[
# 					-0.0325759445452523,
# 					-0.0573790246621843
# 				],
# 				[
# 					0.0247577463929922,
# 					-0.0271968268340614
# 				],
# 				[
# 					0.0102917381800007,
# 					0.139761015298361
# 				],
# 				[
# 					-0.291621148692156,
# 					-0.0722876621608035
# 				],
# 				[
# 					-0.150590549567534,
# 					0.124318859772497
# 				],
# 				[
# 					0.213817704121858,
# 					-0.0239534882612572
# 				],
# 				[
# 					0.157280934839909,
# 					0.0406427982256731
# 				],
# 				[
# 					0.109499059109004,
# 					0.25074415664276
# 				],
# 				[
# 					0.0648612713569942,
# 					-0.22119279652345
# 				],
# 				[
# 					0.145916317053586,
# 					0.106806984655284
# 				],
# 				[
# 					0.238345423809544,
# 					-0.211800362515587
# 				],
# 				[
# 					0.246191680346287,
# 					0.00486997359287555
# 				],
# 				[
# 					0.0865541192384386,
# 					0.161043233453344
# 				],
# 				[
# 					0.0351365289367165,
# 					-0.178839060649372
# 				],
# 				[
# 					-0.232739592336476,
# 					0.0145770112380884
# 				],
# 				[
# 					0.0771600240184859,
# 					0.143661753419119
# 				],
# 				[
# 					-0.218105424237906,
# 					0.00627664376542183
# 				],
# 				[
# 					0.0962597574633164,
# 					0.11605640424853
# 				],
# 				[
# 					0.222661469553473,
# 					0.0517136330548122
# 				],
# 				[
# 					0.0283732928707907,
# 					-0.035171869304866
# 				],
# 				[
# 					-0.314614918256856,
# 					-0.0146825652980117
# 				],
# 				[
# 					0.186753707204026,
# 					-0.0717786940263135
# 				],
# 				[
# 					0.127294657324433,
# 					0.165633538359454
# 				],
# 				[
# 					0.108271387356603,
# 					-0.00763357469293751
# 				],
# 				[
# 					-0.174059216746637,
# 					-0.134429566661766
# 				],
# 				[
# 					0.00743609448587274,
# 					0.0927506325415658
# 				],
# 				[
# 					0.118275011529128,
# 					0.0392625749821938
# 				],
# 				[
# 					0.0185725819217241,
# 					-0.171893972323923
# 				],
# 				[
# 					-0.096134009498982,
# 					-0.110814811519595
# 				],
# 				[
# 					0.310018877243202,
# 					-0.0480217199652028
# 				],
# 				[
# 					-0.170255946413351,
# 					0.22882932305151
# 				],
# 				[
# 					-0.117545709905466,
# 					-0.189417551373303
# 				],
# 				[
# 					-0.0995330168193935,
# 					0.165497374053331
# 				],
# 				[
# 					-0.309891222082972,
# 					-0.144590723741781
# 				],
# 				[
# 					0.0897071758092603,
# 					-0.0353267749955395
# 				],
# 				[
# 					0.0114043213808776,
# 					0.0982937374933085
# 				],
# 				[
# 					0.149100673025763,
# 					-0.0957382083583334
# 				],
# 				[
# 					-0.0405423155020102,
# 					-0.114558776954803
# 				],
# 				[
# 					0.00912527808780205,
# 					-0.180236474972399
# 				],
# 				[
# 					-0.0470659766645159,
# 					-0.0378523209124105
# 				],
# 				[
# 					-0.0688541984372516,
# 					0.174451191016203
# 				],
# 				[
# 					0.0322974139638063,
# 					0.174602120384134
# 				],
# 				[
# 					-0.0167726493842793,
# 					-0.006221524745948
# 				],
# 				[
# 					0.081620533195124,
# 					0.0167989658424774
# 				],
# 				[
# 					0.0579659287996278,
# 					0.163153725807263
# 				],
# 				[
# 					0.22160153853863,
# 					-0.170360987250138
# 				],
# 				[
# 					-0.00999582921641946,
# 					0.0983056237623267
# 				],
# 				[
# 					0.0821750885660637,
# 					0.164797009507977
# 				],
# 				[
# 					0.190058481359904,
# 					0.0773607227431843
# 				],
# 				[
# 					-0.160074483234254,
# 					0.155346780896853
# 				],
# 				[
# 					-0.0694702269068951,
# 					0.176465093682916
# 				],
# 				[
# 					-0.0680308276044743,
# 					-0.241862527774818
# 				],
# 				[
# 					-0.0415331269992689,
# 					-0.0894058126514136
# 				],
# 				[
# 					-0.128013189677059,
# 					-0.163503321571799
# 				],
# 				[
# 					0.141272748928356,
# 					0.00917987193286845
# 				],
# 				[
# 					0.132408692507511,
# 					0.0377657529726918
# 				],
# 				[
# 					0.154517514529425,
# 					0.11810551983316
# 				],
# 				[
# 					0.276965770595463,
# 					0.119203135284683
# 				],
# 				[
# 					-0.19653878562784,
# 					0.11480207159053
# 				],
# 				[
# 					-0.0022453144922867,
# 					0.162510672243674
# 				],
# 				[
# 					0.243373566775992,
# 					-0.0304524901160957
# 				],
# 				[
# 					0.0317895841132539,
# 					0.171225529355922
# 				],
# 				[
# 					0.134105634284669,
# 					0.102981031170467
# 				],
# 				[
# 					-0.173039619281717,
# 					-0.0758840615624358
# 				],
# 				[
# 					-0.166674980261454,
# 					0.197732309464762
# 				],
# 				[
# 					0.00947178401936329,
# 					0.0734551185679669
# 				],
# 				[
# 					0.15879491659797,
# 					0.126674974741722
# 				],
# 				[
# 					0.0200205622293372,
# 					0.0169746722689158
# 				],
# 				[
# 					0.0796529425124668,
# 					0.220541412742734
# 				],
# 				[
# 					-0.173979160601554,
# 					0.143748184111497
# 				],
# 				[
# 					0.193372045382946,
# 					0.0243901081145948
# 				],
# 				[
# 					-0.0844294963273267,
# 					-0.107908034833309
# 				],
# 				[
# 					-0.130158150016231,
# 					-0.0116763671422594
# 				],
# 				[
# 					-0.267191431164502,
# 					-0.149222104917119
# 				],
# 				[
# 					-0.0905109236909995,
# 					0.0570968224096172
# 				],
# 				[
# 					0.234521997923797,
# 					0.0966403134948378
# 				],
# 				[
# 					0.0596833252574384,
# 					-0.166329705037842
# 				],
# 				[
# 					-0.136809717139115,
# 					0.00479786296373852
# 				],
# 				[
# 					-0.142363959207479,
# 					0.173406841637081
# 				],
# 				[
# 					0.140930924073713,
# 					-0.107040646169013
# 				],
# 				[
# 					-0.27017774181624,
# 					-0.0156821240208077
# 				],
# 				[
# 					-0.0166805099818238,
# 					0.133318167205375
# 				],
# 				[
# 					-0.133852372160596,
# 					-0.0884711725100961
# 				],
# 				[
# 					-0.0804440551172714,
# 					0.194718315961985
# 				],
# 				[
# 					0.22751291148331,
# 					0.166103829336991
# 				],
# 				[
# 					0.1320430087042,
# 					0.0571954866806967
# 				],
# 				[
# 					-0.167266696420195,
# 					0.0876511255913338
# 				],
# 				[
# 					-0.311868258423855,
# 					-0.0140858819318904
# 				],
# 				[
# 					-0.0607433286145309,
# 					0.0820760025583335
# 				],
# 				[
# 					0.286161159385936,
# 					-0.0770376509345624
# 				],
# 				[
# 					-0.115421514858467,
# 					0.190872521207834
# 				],
# 				[
# 					0.00448571933442632,
# 					-0.276718822463826
# 				],
# 				[
# 					0.0505809650244076,
# 					-0.311175021564126
# 				],
# 				[
# 					-0.119462716874471,
# 					0.0313934427963369
# 				],
# 				[
# 					0.0655989346353286,
# 					0.288017502570674
# 				],
# 				[
# 					-0.116727770568349,
# 					-0.107338383350157
# 				],
# 				[
# 					0.25286866057829,
# 					-0.109264726340183
# 				],
# 				[
# 					-0.0748068066334892,
# 					-0.0773061762422202
# 				],
# 				[
# 					0.19772812630152,
# 					-0.0253779285520901
# 				],
# 				[
# 					-0.151710378199644,
# 					-0.0247029285924063
# 				],
# 				[
# 					-0.159244830078124,
# 					0.0482525742730974
# 				],
# 				[
# 					-0.0694826847680852,
# 					0.117144758005169
# 				],
# 				[
# 					-0.118503397921397,
# 					0.196144639501941
# 				],
# 				[
# 					0.0962316612406715,
# 					0.0362927601470566
# 				],
# 				[
# 					0.0612608283600025,
# 					0.00657670315327113
# 				],
# 				[
# 					0.0169263964914318,
# 					-0.0792124115134875
# 				],
# 				[
# 					-0.109815560541757,
# 					0.140325603346626
# 				],
# 				[
# 					-0.0592548453361089,
# 					0.159864387112519
# 				],
# 				[
# 					-0.305677487777499,
# 					-0.0182944074667767
# 				],
# 				[
# 					-0.00624408329641535,
# 					-0.12259198455252
# 				],
# 				[
# 					-0.111697709259817,
# 					-0.0146581355204374
# 				],
# 				[
# 					-0.289731437214884,
# 					-0.0512308882677762
# 				],
# 				[
# 					0.146153977942405,
# 					-0.182863405873639
# 				],
# 				[
# 					-0.295279814244993,
# 					-0.166926432234142
# 				],
# 				[
# 					0.065507034925822,
# 					-0.209415319806465
# 				],
# 				[
# 					-0.199389159620925,
# 					-0.128921658050882
# 				],
# 				[
# 					-0.0373727675153494,
# 					0.0725557101251946
# 				],
# 				[
# 					-0.086415364151036,
# 					0.107007740870534
# 				],
# 				[
# 					0.161607134736465,
# 					-0.0375967652653801
# 				],
# 				[
# 					0.288950541486831,
# 					0.0108855657621242
# 				],
# 				[
# 					0.11280316265469,
# 					0.036931631042714
# 				],
# 				[
# 					0.207017829509108,
# 					0.185463755637281
# 				],
# 				[
# 					-0.016976064571186,
# 					-0.0572097656229729
# 				],
# 				[
# 					0.222421057291416,
# 					-0.0719921970062844
# 				],
# 				[
# 					0.0660893529638135,
# 					-0.213364219700627
# 				],
# 				[
# 					-0.0212363526324787,
# 					-0.339977535290538
# 				],
# 				[
# 					0.145474121462191,
# 					0.133587603238242
# 				],
# 				[
# 					-0.181226427879737,
# 					0.125823287704925
# 				],
# 				[
# 					0.0983911767393938,
# 					-0.0314681295985792
# 				],
# 				[
# 					-0.309891222082972,
# 					-0.144590723741781
# 				],
# 				[
# 					-0.174278013512607,
# 					0.0478151385236235
# 				],
# 				[
# 					0.147429823158782,
# 					-0.262720568228525
# 				],
# 				[
# 					-0.126438550892958,
# 					0.0484251881972474
# 				],
# 				[
# 					0.208941953180886,
# 					-0.178816771763539
# 				],
# 				[
# 					0.14227332248535,
# 					0.188346735673411
# 				],
# 				[
# 					-0.125301554241806,
# 					-0.000592416392333785
# 				],
# 				[
# 					-0.178793578753542,
# 					-0.0436455811793644
# 				],
# 				[
# 					-0.0228608694244152,
# 					0.234051140809463
# 				],
# 				[
# 					0.161631981508855,
# 					0.0345494244826991
# 				],
# 				[
# 					0.103457031333368,
# 					0.010516660281185
# 				],
# 				[
# 					-0.194565039350966,
# 					-0.0546363458646757
# 				],
# 				[
# 					0.0349901310499885,
# 					0.0805346150744115
# 				],
# 				[
# 					0.0114137280643163,
# 					-0.0863872094727841
# 				],
# 				[
# 					-0.236912470562448,
# 					-0.112829528672378
# 				],
# 				[
# 					0.314414298413041,
# 					-0.0887975978117973
# 				],
# 				[
# 					0.000452001511446577,
# 					-0.138739516987869
# 				],
# 				[
# 					-0.230834982122732,
# 					0.036790264739203
# 				],
# 				[
# 					-0.0598154132586209,
# 					-0.171447917870307
# 				],
# 				[
# 					0.22507484713409,
# 					-0.0990061903728621
# 				],
# 				[
# 					0.152274611697994,
# 					0.0247180310112837
# 				],
# 				[
# 					-0.134644419932261,
# 					0.0347384066774126
# 				],
# 				[
# 					-0.176218292815248,
# 					-0.00136888421573539
# 				],
# 				[
# 					0.197756613510385,
# 					0.0103967505330403
# 				],
# 				[
# 					-0.122548576581747,
# 					-0.106374053395355
# 				],
# 				[
# 					0.121487083117953,
# 					-0.216752402704888
# 				],
# 				[
# 					0.106225738746756,
# 					0.138196182497161
# 				]
# 			]
# 		},
# 		"z": {
# 			"cluster": [
# 				1,
# 				2,
# 				3,
# 				3,
# 				3,
# 				6,
# 				7,
# 				8,
# 				9,
# 				7,
# 				7,
# 				12,
# 				7,
# 				7,
# 				7,
# 				16,
# 				7,
# 				18,
# 				19,
# 				7,
# 				7,
# 				22,
# 				23,
# 				24,
# 				25,
# 				7,
# 				27,
# 				28,
# 				29,
# 				7,
# 				7,
# 				7,
# 				7,
# 				7,
# 				35,
# 				36,
# 				7,
# 				38,
# 				39,
# 				40,
# 				41,
# 				7,
# 				43,
# 				44,
# 				45,
# 				46,
# 				7,
# 				48,
# 				7,
# 				2,
# 				51,
# 				36,
# 				53,
# 				54,
# 				55,
# 				56,
# 				7,
# 				58,
# 				59,
# 				7,
# 				9,
# 				3,
# 				63,
# 				64,
# 				65,
# 				7,
# 				7,
# 				68,
# 				69,
# 				7,
# 				71,
# 				72,
# 				7,
# 				74,
# 				7,
# 				7,
# 				3,
# 				9,
# 				7,
# 				80,
# 				7,
# 				82,
# 				83,
# 				84,
# 				7,
# 				7,
# 				87,
# 				7,
# 				89,
# 				7,
# 				9,
# 				92,
# 				93,
# 				7,
# 				7,
# 				96,
# 				7,
# 				7,
# 				99,
# 				100,
# 				74,
# 				102,
# 				7,
# 				7,
# 				105,
# 				8,
# 				7,
# 				108,
# 				109,
# 				7,
# 				7,
# 				112,
# 				113,
# 				7,
# 				115,
# 				116,
# 				7,
# 				7,
# 				7,
# 				7,
# 				121,
# 				122,
# 				7,
# 				124,
# 				7,
# 				126,
# 				127,
# 				7,
# 				129,
# 				2,
# 				87,
# 				7,
# 				99,
# 				7,
# 				135,
# 				136,
# 				7,
# 				138,
# 				80,
# 				87,
# 				25,
# 				109,
# 				7,
# 				7,
# 				65,
# 				2,
# 				7,
# 				3,
# 				149,
# 				3,
# 				151,
# 				152,
# 				99,
# 				7,
# 				7,
# 				7,
# 				1,
# 				9,
# 				159,
# 				7,
# 				46,
# 				162,
# 				7,
# 				164,
# 				165,
# 				7,
# 				7,
# 				99,
# 				169,
# 				170,
# 				3,
# 				9
# 			]
# 		},
# 		"t": []
# 	},
# 	"config": {
# 		"graphType": "Scatter2D",
# 		"useFlashIE": true,
# 		"zoomSamplesDisable": true,
# 		"zoomVariablesDisable": true,
# 		"colorBy": "cluster",
# 		"legendPosition": "top",
# 		"heatmapType": "blue-red",
# 		"indicatorCenter": "rainbow-red"
# 	},
# 	"events": {
# 		"click": "/Function(function(o) {detailPopup(o.y.vars);})/",
# 		"dblclick": "/Function(function(o) {detailPopup(o.y.vars);})/"
# 	},
# 	"info": false,
# 	"afterRender": [
# 		[
# 			"setDimensions",
# 			[
# 				1397,
# 				600,
# 				true
# 			]
# 		]
# 	],
# 	"client": "MTU5OTAxNTAxNjE0MTo6MzE4MTIyMTUxMTk1MTcxMTo6MjQuMzo6",
# 	"clientIP": {
# 		"country": "South Korea",
# 		"longitude": 126.9783,
# 		"city": "Seoul",
# 		"latitude": 37.5985,
# 		"continent": "Asia",
# 		"postal": ""
# 	}
# }

# %%
name=json_data['data']['y']["vars"]

# %%
value=json_data['data']['y']["data"]

# %%
data=pd.DataFrame(name)

# %%
x=[]
y=[]
for i in value:
    x.append(i[0])
    y.append(i[1])

# %%
data['x']=x
data['y']=y

# %%
data.rename(columns={0:"name"}, inplace=True)

# %%
data
# Out:
#                          name         x         y
# 0               S_-TIPIFARNIB -0.194565 -0.054636
# 1              11C_-SORAFENIB -0.309891 -0.144591
# 2    5-_11C_methoxy-sunitinib  0.137404 -0.235080
# 3            5-iodo-sunitinib  0.150344 -0.250651
# 4         5-methoxy-sunitinib  0.137404 -0.235080
# ..                        ...       ...       ...
# 167                 VATALANIB -0.176218 -0.001369
# 168              VECABRUTINIB  0.197757  0.010397
# 169               VEMURAFENIB -0.122549 -0.106374
# 170                 VOROLANIB  0.121487 -0.216752
# 171              ZANUBRUTINIB  0.106226  0.138196
#
# [172 rows x 3 columns]

# %%
data.plot.scatter(x='x',y='y')
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
value[0]
# Out:
# [-0.194565039350966, -0.0546363458646758]

# %%
len(y)
# Out:
# 172

# %%
vec=[]

# %%
data1=data

# %%
data1.drop('name',axis=1,inplace=True)
data2=data1

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=5).fit(data1)
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
kmeans.cluster_centers_
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[ 0.01785611, -0.16353798],
#        [-0.11430702,  0.10467356],
#        [ 0.07890734,  0.12651082],
#        [ 0.19898845, -0.02878034],
#        [-0.22501898, -0.06793801]])

# %%
data1['cluster']=kmeans.labels_

# %%
data1.plot.scatter('x', 'y', c='cluster', colormap='gist_rainbow')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
def elbow(x):
    sse=[]
    for i in range(1,11):
        km=KMeans(n_clusters=i, init='k-means++',random_state=0)
        km.fit(x)
        sse.append(km.inertia_)
    plt.plot(range(1,11),sse,marker='o')
    plt.xlabel('n_cluster')
    plt.ylabel('sse')
    plt.show()
             
elbow(data2)

# %%
data1
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             x         y  cluster
# 0   -0.194565 -0.054636        4
# 1   -0.309891 -0.144591        4
# 2    0.137404 -0.235080        0
# 3    0.150344 -0.250651        0
# 4    0.137404 -0.235080        0
# ..        ...       ...      ...
# 167 -0.176218 -0.001369        4
# 168  0.197757  0.010397        3
# 169 -0.122549 -0.106374        4
# 170  0.121487 -0.216752        0
# 171  0.106226  0.138196        2
#
# [172 rows x 3 columns]

# %%
data1['name']=name
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data1
# Out:
#             x         y  cluster                      name
# 0   -0.194565 -0.054636        4             S_-TIPIFARNIB
# 1   -0.309891 -0.144591        4            11C_-SORAFENIB
# 2    0.137404 -0.235080        0  5-_11C_methoxy-sunitinib
# 3    0.150344 -0.250651        0          5-iodo-sunitinib
# 4    0.137404 -0.235080        0       5-methoxy-sunitinib
# ..        ...       ...      ...                       ...
# 167 -0.176218 -0.001369        4                 VATALANIB
# 168  0.197757  0.010397        3              VECABRUTINIB
# 169 -0.122549 -0.106374        4               VEMURAFENIB
# 170  0.121487 -0.216752        0                 VOROLANIB
# 171  0.106226  0.138196        2              ZANUBRUTINIB
#
# [172 rows x 4 columns]

# %%
type(data1)
# Out:
# C:\Users\chris\anaconda3\envs\rdkit\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# pandas.core.frame.DataFrame

# %%
#data1.to_excel('nib_172_kmeans.xlsx',index=False)
